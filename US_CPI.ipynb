# %% [markdown]
# <a href="https://colab.research.google.com/github/harukamasatsugu/US_CPI/blob/main/US_CPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas pandas-datareader gspread oauth2client

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt

start_date = '2020-01-01'
end_date = datetime.date.today()

cpi_data = web.DataReader(["CPIAUCSL"], 'fred', start_date, end_date)
df_cpi_us = cpi_data.pct_change(12)*100
plt.plot(df_cpi_us.index, df_cpi_us)
plt.xlabel('Date')
plt.ylabel('CPI MoM Change (%)')
plt.show()
